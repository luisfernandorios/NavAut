# %% [markdown]
# <a href="https://maestriasydiplomados.tec.mx/posgrados/maestria-en-inteligencia-artificial-aplicada"><img src="logo_MR4010.png"></a>
# <h1> <div align="center"> Dr. David Antonio-Torres</div> </h1>

# %% [markdown]
# # DETECCION DE VEHICULOS CON HOG Y SVM
# ### www.gti.ssr.upm.es/data/Vehicle_database.html

# %% [markdown]
# # Se cargan las bibliotecas necesarias

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import cv2
from skimage.feature import hog

# %% [markdown]
# # Se importan los dos datasets
# ### https://docs.python.org/3/library/glob.html

# %%
import glob
vehicle = glob.glob("data_svm/vehicles/**/*.png")
no_vehicle = glob.glob("data_svm/non-vehicles/**/*.png")

# %%
len(vehicle)
# Out:
# 3425

# %%
len(no_vehicle)
# Out:
# 3900

# %% [markdown]
# # Se muestra una imagen con vehículo

# %%
img_color = cv2.imread(vehicle[10])
plt.imshow(img_color)

# %% [markdown]
# # Para fines de demostración se calcula el HOG de la imagen

# %%
img_gray = cv2.cvtColor(img_color,cv2.COLOR_BGR2GRAY)
plt.imshow(img_gray,cmap="gray")

# %%
features,hog_img = hog(img_gray,
                       orientations = 11,
                       pixels_per_cell = (16,16),
                       cells_per_block = (2,2),
                       transform_sqrt = False,
                       visualize = True,
                       feature_vector = True)

# %%
features.shape
# Out:
# (396,)

# %%
hog_img.shape
# Out:
# (64, 64)

# %%
plt.imshow(hog_img,cmap = 'gray')

# %% [markdown]
# # Se extraen las features del HOG para ambos tipos de datos

# %%
vehicle_hog_accum = []

for i in vehicle:
    img_color = mpimg.imread(i)
    img_gray = cv2.cvtColor(img_color,cv2.COLOR_BGR2GRAY)
    
    vehicle_hog_feature, vehicle_hog_img = hog(img_gray,
                                               orientations = 11,
                                               pixels_per_cell = (16,16),
                                               cells_per_block = (2,2),
                                               transform_sqrt = False,
                                               visualize = True,
                                               feature_vector = True)
    
    vehicle_hog_accum.append(vehicle_hog_feature)

# %%
X_vehicle = np.vstack(vehicle_hog_accum).astype(np.float64)
y_vehicle = np.ones(len(X_vehicle))

# %%
X_vehicle.shape
# Out:
# (3425, 396)

# %%
y_vehicle.shape
# Out:
# (3425,)

# %%
novehicle_hog_accum = []

for i in no_vehicle:
    img_color = mpimg.imread(i)
    img_gray = cv2.cvtColor(img_color,cv2.COLOR_BGR2GRAY)
    
    novehicle_hog_feature, novehicle_hog_img = hog(img_gray,
                                               orientations = 11,
                                               pixels_per_cell = (16,16),
                                               cells_per_block = (2,2),
                                               transform_sqrt = False,
                                               visualize = True,
                                               feature_vector = True)
    
    novehicle_hog_accum.append(novehicle_hog_feature)

# %%
X_novehicle = np.vstack(novehicle_hog_accum).astype(np.float64)
y_novehicle = np.zeros(len(X_novehicle))

# %%
X_novehicle.shape
# Out:
# (3900, 396)

# %%
y_novehicle.shape
# Out:
# (3900,)

# %% [markdown]
# # Se combinan ambos tipos de datos para alimentar el SVM

# %%
X = np.vstack((X_vehicle,X_novehicle))
X.shape
# Out:
# (7325, 396)

# %%
y = np.hstack((y_vehicle,y_novehicle))
y.shape
# Out:
# (7325,)

# %% [markdown]
# # Se generan los datos de entrenamiento y de prueba

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 42)

# %%
X_train.shape
# Out:
# (5127, 396)

# %%
X_test.shape
# Out:
# (2198, 396)

# %% [markdown]
# # Se importa el Clasificador y se entrena

# %%
#from sklearn.svm import LinearSVC

#svc_model = LinearSVC()
#svc_model.fit(X_train, y_train)
from sklearn.svm import SVC

svc_model = SVC()
svc_model.fit(X_train,y_train)
# Out:
# SVC()

# %%
y_predict = svc_model.predict(X_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix

cm = confusion_matrix(y_test,y_predict)
sns.heatmap(cm, annot=True, fmt = "d")
# Out:
# <AxesSubplot: >

# %%
print(classification_report(y_test,y_predict))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.98      0.98      0.98      1154
#          1.0       0.98      0.97      0.98      1044
#
#     accuracy                           0.98      2198
#    macro avg       0.98      0.98      0.98      2198
# weighted avg       0.98      0.98      0.98      2198

# %% [markdown]
# # GridSearchCV

# %%
param_grid = {'C': [0.1,1, 10, 100, 1000], 'gamma': [1,0.1,0.01,0.001,0.0001], 'kernel': ['rbf']}

# %%
from sklearn.model_selection import GridSearchCV

grid = GridSearchCV(SVC(),param_grid,refit=True,verbose=4)
grid.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# [CV 1/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.954 total time=   4.7s
# [CV 2/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.941 total time=   4.5s
# [CV 3/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.931 total time=   4.4s
# [CV 4/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.950 total time=   4.5s
# [CV 5/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.950 total time=   4.5s
# [CV 1/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.955 total time=   2.6s
# [CV 2/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.952 total time=   2.8s
# [CV 3/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.952 total time=   2.7s
# [CV 4/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.963 total time=   2.7s
# [CV 5/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.964 total time=   2.7s
# [CV 1/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.928 total time=   5.7s
# [CV 2/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.927 total time=   5.6s
# [CV 3/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.915 total time=   5.5s
# [CV 4/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.931 total time=   5.6s
# [CV 5/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.930 total time=   5.6s
# [CV 1/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.536 total time=   6.9s
# [CV 2/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.535 total time=   7.0s
# [CV 3/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.536 total time=   7.0s
# [CV 4/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.536 total time=   7.1s
# [CV 5/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.536 total time=   6.9s
# [CV 1/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.536 total time=   7.0s
# [CV 2/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.535 total time=   7.5s
# [CV 3/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.536 total time=   7.4s
# [CV 4/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.536 total time=   7.1s
# [CV 5/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.536 total time=   7.7s
# [CV 1/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.987 total time=   4.1s
# [CV 2/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.983 total time=   3.9s
# [CV 3/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.977 total time=   3.7s
# [CV 4/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.981 total time=   4.2s
# [CV 5/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.980 total time=   3.9s
# [CV 1/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.969 total time=   1.5s
# [CV 2/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.972 total time=   1.5s
# [CV 3/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.962 total time=   1.3s
# [CV 4/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.965 total time=   1.5s
# [CV 5/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.970 total time=   1.6s
# [CV 1/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.949 total time=   2.9s
# [CV 2/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.948 total time=   2.7s
# [CV 3/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.944 total time=   2.8s
# [CV 4/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.957 total time=   2.7s
# [CV 5/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.957 total time=   2.6s
# [CV 1/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.925 total time=   6.3s
# [CV 2/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.926 total time=   5.8s
# [CV 3/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.912 total time=   6.1s
# [CV 4/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.930 total time=   5.9s
# [CV 5/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.929 total time=   6.2s
# [CV 1/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.536 total time=   7.5s
# [CV 2/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.535 total time=   7.3s
# [CV 3/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.536 total time=   7.4s
# [CV 4/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.536 total time=   7.7s
# [CV 5/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.536 total time=   7.6s
# [CV 1/5] END .........C=10, gamma=1, kernel=rbf;, score=0.987 total time=   3.7s
# [CV 2/5] END .........C=10, gamma=1, kernel=rbf;, score=0.983 total time=   3.5s
# [CV 3/5] END .........C=10, gamma=1, kernel=rbf;, score=0.979 total time=   3.5s
# [CV 4/5] END .........C=10, gamma=1, kernel=rbf;, score=0.983 total time=   3.5s
# [CV 5/5] END .........C=10, gamma=1, kernel=rbf;, score=0.982 total time=   3.4s
# [CV 1/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.979 total time=   0.9s
# [CV 2/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.984 total time=   0.9s
# [CV 3/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.980 total time=   0.9s
# [CV 4/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.986 total time=   0.8s
# [CV 5/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.980 total time=   0.9s
# [CV 1/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.957 total time=   1.2s
# [CV 2/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.964 total time=   1.3s
# [CV 3/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.954 total time=   1.3s
# [CV 4/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.963 total time=   1.3s
# [CV 5/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.963 total time=   1.3s
# [CV 1/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.946 total time=   2.5s
# [CV 2/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.948 total time=   2.5s
# [CV 3/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.942 total time=   2.4s
# [CV 4/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.955 total time=   2.4s
# [CV 5/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.954 total time=   2.5s
# [CV 1/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.925 total time=   5.5s
# [CV 2/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.926 total time=   5.9s
# [CV 3/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.912 total time=   6.1s
# [CV 4/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.930 total time=   6.0s
# [CV 5/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.930 total time=   6.1s
# [CV 1/5] END ........C=100, gamma=1, kernel=rbf;, score=0.987 total time=   3.5s
# [CV 2/5] END ........C=100, gamma=1, kernel=rbf;, score=0.983 total time=   3.6s
# [CV 3/5] END ........C=100, gamma=1, kernel=rbf;, score=0.979 total time=   3.5s
# [CV 4/5] END ........C=100, gamma=1, kernel=rbf;, score=0.983 total time=   3.6s
# [CV 5/5] END ........C=100, gamma=1, kernel=rbf;, score=0.982 total time=   3.9s
# [CV 1/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.980 total time=   0.9s
# [CV 2/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.983 total time=   0.9s
# [CV 3/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.980 total time=   0.9s
# [CV 4/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.983 total time=   0.9s
# [CV 5/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.978 total time=   1.0s
# [CV 1/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.961 total time=   1.0s
# [CV 2/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.967 total time=   1.0s
# [CV 3/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.964 total time=   0.9s
# [CV 4/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.968 total time=   1.0s
# [CV 5/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.972 total time=   0.9s
# [CV 1/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.955 total time=   1.4s
# [CV 2/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.964 total time=   1.3s
# [CV 3/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.951 total time=   1.5s
# [CV 4/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.964 total time=   1.3s
# [CV 5/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.963 total time=   1.3s
# [CV 1/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.946 total time=   2.5s
# [CV 2/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.948 total time=   2.6s
# [CV 3/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.942 total time=   2.3s
# [CV 4/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.955 total time=   2.5s
# [CV 5/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.954 total time=   2.5s
# [CV 1/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.987 total time=   3.5s
# [CV 2/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.983 total time=   3.4s
# [CV 3/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.979 total time=   3.5s
# [CV 4/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.983 total time=   3.9s
# [CV 5/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.982 total time=   3.8s
# [CV 1/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.980 total time=   0.9s
# [CV 2/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.983 total time=   0.9s
# [CV 3/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.980 total time=   0.8s
# [CV 4/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.983 total time=   0.9s
# [CV 5/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.978 total time=   0.9s
# [CV 1/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.963 total time=   0.9s
# [CV 2/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.973 total time=   1.0s
# [CV 3/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.967 total time=   0.9s
# [CV 4/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.971 total time=   0.9s
# [CV 5/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.974 total time=   1.1s
# [CV 1/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.957 total time=   1.1s
# [CV 2/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.966 total time=   1.1s
# [CV 3/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.954 total time=   1.0s
# [CV 4/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.963 total time=   1.0s
# [CV 5/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.961 total time=   1.1s
# [CV 1/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.955 total time=   1.5s
# [CV 2/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.964 total time=   1.5s
# [CV 3/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.950 total time=   1.5s
# [CV 4/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.964 total time=   1.5s
# [CV 5/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.963 total time=   1.5s
# GridSearchCV(estimator=SVC(),
#              param_grid={'C': [0.1, 1, 10, 100, 1000],
#                          'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
#                          'kernel': ['rbf']},
#              verbose=4)

# %%
grid.best_params_
# Out:
# {'C': 10, 'gamma': 1, 'kernel': 'rbf'}

# %%
grid.best_estimator_
# Out:
# SVC(C=10, gamma=1)

# %%
grid_predictions = grid.predict(X_test)

# %%
cm = confusion_matrix(y_test,grid_predictions)
sns.heatmap(cm, annot=True, fmt = "d")
# Out:
# <AxesSubplot: >

# %%
print(classification_report(y_test,grid_predictions))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.98      0.99      0.98      1154
#          1.0       0.99      0.98      0.98      1044
#
#     accuracy                           0.98      2198
#    macro avg       0.98      0.98      0.98      2198
# weighted avg       0.98      0.98      0.98      2198

# %% [markdown]
# # Gracias por la atención
